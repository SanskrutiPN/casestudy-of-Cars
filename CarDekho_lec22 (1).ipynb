# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('car_dekho.csv')
print(df.to_string())
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0                         ritz  2014           3.35          5.590       27000    Petrol      Dealer       Manual      0
# 1                          sx4  2013           4.75          9.540       43000    Diesel      Dealer       Manual      0
# 2                         ciaz  2017           7.25          9.850        6900    Petrol      Dealer       Manual      0
# 3                      wagon r  2011           2.85          4.150        5200    Petrol      Dealer       Manual      0
# 4                        swift  2014           4.60          6.870       42450    Diesel      Dealer       Manual      0
# 5                vitara brezza  2018           9.25          9.830        2071    Diesel      Dealer       Manual      0
# 6                         ciaz  2015           6.75          8.120       18796    Petrol      Dealer       Manual      0
# ...

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# ...

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
# fuel=df['Fuel_Type'].value_counts()

# c=['green','orange','red']
# fuel.plot(kind='pie',color=c)


fuel=df['Fuel_Type'].value_counts()

c=['green','orange','red']
fuel.plot(kind='bar',width=0.5,color=c)
plt.grid(axis='y')
plt.title('Fuel distribution')
plt.ylabel('Car count')
plt.plot()
# Out:
# []

# %%
tr=df['Transmission'].value_counts()
c=['green','orange']
tr.plot(kind='pie',color=c)
plt.grid(axis='y')
plt.legend()
plt.title('Transmission')
plt.plot()
# Out:
# []

# %%
tr=df['Transmission'].value_counts()
c=['green','orange']
tr.plot(kind='bar',color=c)
plt.grid(axis='y')
plt.ylabel("Car count")
plt.title('Transmission')
plt.plot()
# Out:
# []

# %%
yr=df['Year'].value_counts()
c=['blue','brown']
yr.plot(kind='bar',color=c)
plt.ylabel('Car_count')
plt.grid(axis='y')
plt.legend()
plt.title('Count by Year')
plt.plot()
# Out:
# []

# %%
yr=df['Year'].value_counts()
c=['blue','brown']
yr.plot(kind='pie',color=c)
plt.grid(axis='y')
plt.legend()
plt.title('Count by Year')
plt.plot()
# Out:
# []

# %%
s=df['Seller_Type'].value_counts()
c=['blue','gray']
s.plot(kind='bar',color=c)
plt.ylabel('Car_count')
plt.grid(axis='y')
plt.legend()
plt.title('Analysing type of sells')
plt.plot()
# Out:
# []

# %%
s=df['Seller_Type'].value_counts()
c=['blue','brown']
s.plot(kind='pie')
plt.grid(axis='y')
plt.legend()
plt.title('Analysing type of sells')
plt.plot()
# Out:
# []

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %% [markdown]
# There are 301 rows of data and 9 columns in csv file
# There  is no null value in data
# There are three Fuel Types:((Petrol, 239),(Diesel, 60),(CNG, 2))
# Transmission include two types:((Manual,261),(Automatic,40))
# Seller type includes two types:((Dealer, 195),(Individual, 106))

# %%
# Pairplot for numerical features
sns.pairplot(df.select_dtypes(include=[np.number]))
plt.show()
# Out:
# C:\Users\Sanskruti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sanskruti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sanskruti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Categorical Data Analysis
for col in df.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Outlier Detection using Boxplots
for col in df.select_dtypes(include=[np.number]).columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
# C:\Users\Sanskruti\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# Convert non-numeric columns to category
df_numeric = df.apply(lambda col: pd.to_numeric(col, errors='coerce') if col.dtype == 'object' else col)

# Drop non-numeric columns for correlation heatmap
df_numeric = df_numeric.select_dtypes(include=[np.number])
